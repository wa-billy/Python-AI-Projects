# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv.imread('156a941bd9771bd52674008ee1b4461f.jpg')
gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')

# %%
blur = cv.GaussianBlur(gray, (11, 11), 0)
plt.imshow(blur, cmap="gray")

# %%
canny = cv.Canny(blur, 10, 310, 3)
plt.imshow(canny, cmap='gray')

# %%
dilated = cv.dilate(canny, (1, 1), iterations=0)
plt.imshow(dilated, cmap='gray')

# %%
(cnt, hierarchy) = cv.findContours(
    dilated.copy(), cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE
)
rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)
cv.drawContours(rgb, cnt, -1, (0, 255, 0), 2)

plt.imshow(rgb)

# %%
print(f'coins in the image: {len(cnt)}')
# Out:
# coins in the image: 12
