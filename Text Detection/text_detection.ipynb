# %%
import cv2 as cv
import pytesseract
from matplotlib import pyplot as plt
import numpy as np

# %%
image = cv.imread("1cec9ec86993dce9d53a9309577c8276.jpg")
image_rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.axis("off")
plt.show()

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR/tesseract.exe'
extracted_text = pytesseract.image_to_string(image_rgb)
print(extracted_text)
# Out:
# bro
# (romantically)

# %%
data = pytesseract.image_to_data(
    image_rgb, output_type=pytesseract.Output.DICT
)
data
# Out:
# {'level': [1, 2, 3, 4, 5, 4, 5],
#  'page_num': [1, 1, 1, 1, 1, 1, 1],
#  'block_num': [0, 1, 1, 1, 1, 1, 1],
#  'par_num': [0, 0, 1, 1, 1, 1, 1],
#  'line_num': [0, 0, 0, 1, 1, 2, 2],
#  'word_num': [0, 0, 0, 0, 1, 0, 1],
#  'left': [0, 52, 52, 53, 53, 52, 52],
#  'top': [0, 248, 248, 248, 248, 377, 377],
#  'width': [736, 630, 630, 146, 146, 630, 630],
#  'height': [753, 253, 253, 97, 97, 124, 124],
#  'conf': [-1, -1, -1, -1, 96, -1, 96],
#  'text': ['', '', '', '', 'bro', '', '(romantically)']}

# %%
n_boxes = len(data['level'])
for i in range(n_boxes):
    (x, y, w, h) = (
        data['left'][i], data['top'][i],
        data['width'][i], data['height'][i]
    )
    
    cv.rectangle(image_rgb, (x, y), (x + w, y + h), (255, 0, 0), 2)

# %%
plt.figure(figsize=(10, 6))
plt.imshow(image_rgb)
plt.axis("off")
plt.show()
