# %%
import torch
import torch.nn as nn
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.autograd import Variable

# %%
batch_size = 64

train_dataset = datasets.MNIST(
    root='./data',
    train=True,
    transform=transforms.ToTensor(),
    download=True
)

test_dataset = datasets.MNIST(
    root='./data',
    train=False,
    transform=transforms.ToTensor()
)

train_loader = torch.utils.data.DataLoader(
    dataset=train_dataset, batch_size=batch_size,
    shuffle=True
)

test_loader = torch.utils.data.DataLoader(
    dataset=test_dataset, batch_size=batch_size,
    shuffle=False
)

# %%
input_size = 784
num_classes = 10
num_epochs = 5
batch_size = 100
learning_rate = 0.001

# %%
class LogisticRegression(nn.Module):
    def __init__(self, input_size, num_classes):
        super(LogisticRegression, self).__init__()
        self.linear = nn.Linear(input_size, num_classes)

    def forward(self, x):
        out = self.linear(x)
        return out

# %%
model = LogisticRegression(input_size, num_classes)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)

# %%
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = Variable(images.view(-1, 28 * 28))
        labels = Variable(labels)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        if (i + 1) % 100 == 0:
            print('Epoch: [% d/% d], Step: [% d,% d], Loss: %.4f'
                  % (epoch + 1, num_epochs, i + 1,
                     len(train_dataset) // batch_size, loss.item()))
# Out:
# Epoch: [ 1/ 5], Step: [ 100, 600], Loss: 1.5319
# Epoch: [ 1/ 5], Step: [ 200, 600], Loss: 1.1503
# Epoch: [ 1/ 5], Step: [ 300, 600], Loss: 1.0565
# Epoch: [ 1/ 5], Step: [ 400, 600], Loss: 1.0266
# Epoch: [ 1/ 5], Step: [ 500, 600], Loss: 0.7657
# Epoch: [ 1/ 5], Step: [ 600, 600], Loss: 0.7428
# Epoch: [ 1/ 5], Step: [ 700, 600], Loss: 0.6963
# Epoch: [ 1/ 5], Step: [ 800, 600], Loss: 0.5793
# Epoch: [ 1/ 5], Step: [ 900, 600], Loss: 0.6176
# Epoch: [ 2/ 5], Step: [ 100, 600], Loss: 0.6108
# Epoch: [ 2/ 5], Step: [ 200, 600], Loss: 0.6335
# Epoch: [ 2/ 5], Step: [ 300, 600], Loss: 0.6137
# Epoch: [ 2/ 5], Step: [ 400, 600], Loss: 0.3922
# Epoch: [ 2/ 5], Step: [ 500, 600], Loss: 0.5388
# Epoch: [ 2/ 5], Step: [ 600, 600], Loss: 0.5685
# Epoch: [ 2/ 5], Step: [ 700, 600], Loss: 0.3752
# Epoch: [ 2/ 5], Step: [ 800, 600], Loss: 0.3775
# Epoch: [ 2/ 5], Step: [ 900, 600], Loss: 0.5051
# Epoch: [ 3/ 5], Step: [ 100, 600], Loss: 0.4631
# Epoch: [ 3/ 5], Step: [ 200, 600], Loss: 0.6034
# Epoch: [ 3/ 5], Step: [ 300, 600], Loss: 0.4190
# Epoch: [ 3/ 5], Step: [ 400, 600], Loss: 0.4997
# Epoch: [ 3/ 5], Step: [ 500, 600], Loss: 0.6108
# Epoch: [ 3/ 5], Step: [ 600, 600], Loss: 0.4881
# Epoch: [ 3/ 5], Step: [ 700, 600], Loss: 0.5111
# Epoch: [ 3/ 5], Step: [ 800, 600], Loss: 0.4326
# Epoch: [ 3/ 5], Step: [ 900, 600], Loss: 0.4548
# Epoch: [ 4/ 5], Step: [ 100, 600], Loss: 0.5122
# Epoch: [ 4/ 5], Step: [ 200, 600], Loss: 0.3854
# Epoch: [ 4/ 5], Step: [ 300, 600], Loss: 0.3426
# Epoch: [ 4/ 5], Step: [ 400, 600], Loss: 0.3661
# Epoch: [ 4/ 5], Step: [ 500, 600], Loss: 0.4265
# Epoch: [ 4/ 5], Step: [ 600, 600], Loss: 0.5682
# Epoch: [ 4/ 5], Step: [ 700, 600], Loss: 0.6079
# Epoch: [ 4/ 5], Step: [ 800, 600], Loss: 0.4407
# Epoch: [ 4/ 5], Step: [ 900, 600], Loss: 0.3993
# Epoch: [ 5/ 5], Step: [ 100, 600], Loss: 0.3133
# Epoch: [ 5/ 5], Step: [ 200, 600], Loss: 0.6164
# Epoch: [ 5/ 5], Step: [ 300, 600], Loss: 0.2945
# Epoch: [ 5/ 5], Step: [ 400, 600], Loss: 0.3287
# Epoch: [ 5/ 5], Step: [ 500, 600], Loss: 0.5371
# Epoch: [ 5/ 5], Step: [ 600, 600], Loss: 0.3331
# Epoch: [ 5/ 5], Step: [ 700, 600], Loss: 0.5611
# Epoch: [ 5/ 5], Step: [ 800, 600], Loss: 0.2240
# Epoch: [ 5/ 5], Step: [ 900, 600], Loss: 0.5023

# %%
correct = 0
total = 0
for images, labels in test_loader:
    images = Variable(images.view(-1, 28 * 28))
    outputs = model(images)
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum()

print('Accuracy of the model on the 10000 test images: % d %%' % (
    100 * correct / total
))
# Out:
# Accuracy of the model on the 10000 test images:  89 %
